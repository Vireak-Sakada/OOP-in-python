# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmok4081-bit/OOP-in-python/blob/main/class_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Person:
  def __init__(self,name,age):
      self.name = name
      self.age = age
dog1 = Person("sakada", 14)
dog2 = Person("Max", 5)
print(dog1.name)
print(dog1.age)
# Out:
# sakada
# 14

# %%
#methot is like the action inside the class

# %%
class Dog:
  def __init__(self,name,age):
    self.name = name
    self.age = age
  def bark(self):
    print("woff!")
dog1 = Dog("bubby",3)
